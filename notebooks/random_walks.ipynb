# %% [markdown]
# [Random walk (Wikipedia)](https://en.wikipedia.org/wiki/Random_walk)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import random
position = 0
walk = [position]
steps = 1_000
for i in range(steps):
    step = 1 if random.randint(0, 1) else -1
    position += step
    walk.append(position)

# %%
plt.plot(walk[:100])

# %%
nsteps = 1000
draws = np.random.randint(0, 2, size=nsteps)
steps = np.where(draws > 0, 1, -1)
walk = steps.cumsum()

# %%
plt.plot(walk[:100])

# %%
walk.min()
# Out:
# -49

# %%
walk.max()
# Out:
# 0

# %%
plt.plot(np.abs(walk))

# %%
plt.plot(np.abs(walk) >= 10)

# %%
(np.abs(walk) >= 10).argmax()
# Out:
# 31

# %%
nwalks = 5_000
nsteps = 1_000
draws = np.random.randint(0, 2, size=(nwalks, nsteps))
steps = np.where(draws > 0, 1, -1)
walks = steps.cumsum(axis=1)
walks
# Out:
# array([[ -1,  -2,  -3, ...,  10,  11,  10],
#        [  1,   0,  -1, ...,  24,  23,  24],
#        [  1,   0,  -1, ...,  42,  43,  42],
#        ...,
#        [  1,   0,  -1, ..., -16, -17, -18],
#        [  1,   0,   1, ...,  50,  49,  50],
#        [ -1,   0,  -1, ...,  16,  15,  14]])

# %%
walks.max()
# Out:
# 112

# %%
walks.min()
# Out:
# -133

# %%
hits30 = (np.abs(walks) >= 30).any(1)
hits30
# Out:
# array([False,  True,  True, ..., False,  True,  True])

# %%
hits30.sum()
# Out:
# 3333

# %%
crossing_times = (np.abs(walks[hits30]) >= 30).argmax(1)
crossing_times
# Out:
# array([437, 275, 201, ..., 385, 613, 343])

# %%
crossing_times.mean()
# Out:
# 504.05190519051905
